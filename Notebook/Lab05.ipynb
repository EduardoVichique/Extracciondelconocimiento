# %%
import pandas as pd
import numpy as np
import random

# %%
from faker import Faker

# %%
pip install Faker
# Out:
# Collecting Faker
#   Downloading faker-40.21.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: tzdata in c:\users\eduar\anaconda3\lib\site-packages (from Faker) (2025.2)
# Downloading faker-40.21.0-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ---------- ----------------------------- 0.5/2.0 MB 1.4 MB/s eta 0:00:02
#    --------------- ------------------------ 0.8/2.0 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 2.9 MB/s  0:00:01
# Installing collected packages: Faker
# Successfully installed Faker-40.21.0
# Note: you may need to restart the kernel to use updated packages.

# %%
fake = Faker ("es_MX")

# %%
datos = []
for i in range(100):
    datos.append(
        {
            "id_usuario": i +1,
            "nombre": fake.name(),
            "correo": fake.email(),
            "edad": random.randint(18, 65),
            "seguidores" : random.randint(50, 5000),
            "plataformas": random.choice(["TikTok", "Instagram", "Youtube"])
        }
    )

# %%
dfInfluencer = pd.DataFrame(datos)

# %%
dfInfluencer
# Out:
#     id_usuario                         nombre                       correo  \
# 0            1            Ing. Armando Avilés       wilfrido55@example.com
# 1            2             Felix Leyva Ávalos  adalbertocastro@example.net
# 2            3         Horacio Granado Valdez   adancandelaria@example.org
# 3            4                   Pablo Orosco    blancoantonio@example.org
# 4            5            Sr. Ramiro Rentería  de-la-rosaoscar@example.org
# ..         ...                            ...                          ...
# 95          96        Camilo Pedroza Elizondo    luis-miguel80@example.com
# 96          97         José Eduardo Caballero        minerva05@example.net
# 97          98        Estela Mascareñas Brito          jesus29@example.com
# 98          99  Marco Antonio Corrales Rosado           adan53@example.com
# 99         100                 Alicia Naranjo  mascarenasmario@example.net
#
#     edad  seguidores plataformas
# 0     60        1101   Instagram
# 1     59         377   Instagram
# 2     30         129     Youtube
# 3     37        1965      TikTok
# 4     39        4660      TikTok
# ..   ...         ...         ...
# 95    59        1640     Youtube
# 96    28        1250     Youtube
# 97    59         419   Instagram
# 98    57         897   Instagram
# 99    42        1855     Youtube
#
# [100 rows x 6 columns]

# %%
dfInfluencer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_usuario   100 non-null    int64
#  1   nombre       100 non-null    object
#  2   correo       100 non-null    object
#  3   edad         100 non-null    int64
#  4   seguidores   100 non-null    int64
#  5   plataformas  100 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 4.8+ KB

# %%
dfInfluencer.describe()
# Out:
#        id_usuario        edad   seguidores
# count  100.000000  100.000000   100.000000
# mean    50.500000   40.150000  2245.630000
# std     29.011492   14.003156  1415.817911
# min      1.000000   18.000000   129.000000
# 25%     25.750000   28.000000   973.500000
# 50%     50.500000   39.000000  2022.500000
# 75%     75.250000   54.500000  3323.250000
# max    100.000000   64.000000  4864.000000

# %%
dfInfluencer.describe(include="all")
# Out:
#         id_usuario               nombre                  correo        edad  \
# count   100.000000                  100                     100  100.000000
# unique         NaN                  100                     100         NaN
# top            NaN  Ing. Armando Avilés  wilfrido55@example.com         NaN
# freq           NaN                    1                       1         NaN
# mean     50.500000                  NaN                     NaN   40.150000
# std      29.011492                  NaN                     NaN   14.003156
# min       1.000000                  NaN                     NaN   18.000000
# 25%      25.750000                  NaN                     NaN   28.000000
# 50%      50.500000                  NaN                     NaN   39.000000
# 75%      75.250000                  NaN                     NaN   54.500000
# max     100.000000                  NaN                     NaN   64.000000
#
#          seguidores plataformas
# count    100.000000         100
# unique          NaN           3
# top             NaN   Instagram
# freq            NaN          35
# mean    2245.630000         NaN
# std     1415.817911         NaN
# min      129.000000         NaN
# 25%      973.500000         NaN
# 50%     2022.500000         NaN
# 75%     3323.250000         NaN
# max     4864.000000         NaN

# %%
# Graficar

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Graficamos

plt.figure(figsize = (8,4))
sns.histplot(dfInfluencer["edad"], bins=10)
plt.title("Distribucion de edades")
plt.show()

# %%
# Graficamos la cantidad de usuarios por plataforma

plt.figure(figsize=(8,4))
sns.countplot(x="plataformas", data = dfInfluencer)
plt.title("Cantidad de usuarios por plataforma")
plt.show()
